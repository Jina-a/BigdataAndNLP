# %%
import os
import numpy as np
import pandas as pd

df = pd.read_excel('/content/20220101_20220113_네이버_네이버_기사.xlsx')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-2f75793fb3c9> in <module>()
#       3 import pandas as pd
#       4
# ----> 5 df = pd.read_excel('/content/20220101_20220113_네이버_네이버_기사.xlsx')
#       6 df
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
# ...

# %%
title_list = df['제목'].values.tolist()
title_slice = []
for i in range(0, len(title_list)):
    title_slice += title_list[i].split(' ')
len(title_slice)
# Out:
# 98577

# %%
titleCount = {} 
 
for title in title_slice:
    titleCount[title] = titleCount.get(title, 0) + 1
    titleKeys = sorted(titleCount.keys())

# %%
for word in titleKeys:
    if titleCount[word] > 20:
        print(word + ':' + str(titleCount[word]))
# Out:
# "글로벌:49
# "남궁훈:41
# "메타버스:64
# "미래성장:21
# "방금:43
# "새:23
# '2022:23
# 'AI:53
# 'NFT':65
# 'SLL'로:32
# '견(犬)옥고':53
# '견옥고':91
# '과태료':29
# '기아:278
# '낚시성:31
# '낚시성':30
# '내일':207
# '네이비필드':92
# '뉴:53
# '닥터매거진':47
# '담양장터:52
# '로즈:84
# '부산인디커넥트페스티벌:21
# '삼성:136
# '세계:38
# '세계에서:168
# '아이스:25
# '옵스나우-G':39
# '이북:24
# '인공지능:28
# '정과장':27
# '조달청:229
# '카카오':21
# '키움:44
# '타임디펜더스':31
# '팔라독:48
# 1%:61
# 1000만:48
# 100대:528
# 100만:21
# 11종으로:22
# 1’:25
# 1년:69
# 1위:114
# 1인:79
# 1일:37
# 2%:41
# 20%:22
# 2022:80
# 2022':33
# 2022,:33
# 20일:45
# 210개:25
# 210개소:74
# 210개소에:165
# 210곳:37
# 210곳에:104
# 27기:21
# 2년:402
# 3%:25
# 30일:32
# 31일:101
# 3년간:67
# 3만:29
# 3만7000건:31
# 3만7700건…4월부터:29
# 3만7700여건:29
# 3만7705건:57
# 3월:33
# 4년:25
# 4월:124
# 4월부터:110
# 5G:38
# 5탄:25
# 6%:21
# 6개:52
# 6일:36
# 6종:133
# 7종으로:34
# 9월:79
# AI:164
# AI로봇:25
# CAC장:39
# CAC장,:21
# CJ:25
# CNS,:31
# EDU:171
# ENM:21
# EV:534
# GC녹십자웰빙,:75
# GTOUR':49
# ICT:37
# JTBC스튜디오,:82
# KBO:78
# KGC인삼공사,:186
# KOSEF:54
# ...
