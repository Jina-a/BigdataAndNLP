# %% [markdown]
# # **🟠기업별 주가 그래프 및 키워드 기반 기사 정리🟠**

# %%
# !pip install finance-datareader
# Out:
# ...
#      |████████████████████████████████| 48 kB 1.8 MB/s
# ...

# %%
import FinanceDataReader as fdr
df_krx = fdr.StockListing('KRX')

# %%
df = fdr.DataReader('259960','2022-03-28', '2022-04-04')
df
# Out:
#               Open    High     Low   Close  Volume    Change
# Date
# 2022-03-28  278500  279000  270500  271500  192699 -0.025135
# 2022-03-29  273000  275500  271000  273000  173269  0.005525
# 2022-03-30  274500  276500  271000  272500  147316 -0.001832
# 2022-03-31  272500  281500  272000  275500  187476  0.011009
# 2022-04-01  276500  278000  272000  278000  125727  0.009074
# 2022-04-04  275500  299500  275500  298500  507532  0.073741

# %%
from matplotlib import pyplot as plt
plt.plot(df['High'], 'bo-')
plt.xticks(rotation=45)
# Out:
# (array([738242., 738243., 738244., 738245., 738246., 738247., 738248.,
#         738249.]), <a list of 8 Text major ticklabel objects>)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df = fdr.DataReader('377300','2022-03-28', '2022-04-04')
from matplotlib import pyplot as plt
plt.plot(df['High'], 'bo-')
plt.xticks(rotation=45)
# Out:
# (array([738242., 738243., 738244., 738245., 738246., 738247., 738248.,
#         738249.]), <a list of 8 Text major ticklabel objects>)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df = fdr.DataReader('005380','2022-03-28', '2022-04-04')
from matplotlib import pyplot as plt
plt.plot(df['High'], 'bo-')
plt.xticks(rotation=45)
# Out:
# (array([738242., 738243., 738244., 738245., 738246., 738247., 738248.,
#         738249.]), <a list of 8 Text major ticklabel objects>)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df = fdr.DataReader('003490','2022-03-28', '2022-04-04')
from matplotlib import pyplot as plt
plt.plot(df['High'], 'bo-')
plt.xticks(rotation=45)
# Out:
# (array([738242., 738243., 738244., 738245., 738246., 738247., 738248.,
#         738249.]), <a list of 8 Text major ticklabel objects>)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
